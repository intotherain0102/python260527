# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.plot(np.arange(10))

# %%
import pandas as pd
from pandas import Series, DataFrame

myCampus = Series([100, 200, 300, 400, 500], index=['2026-05-01', '2026-05-02', '2026-05-03', '2026-05-04', '2026-05-05'])

# slice
myCampus["2026-05-05"]
# Out:
# np.int64(500)

# %%
# dataframe

date = {'foreigner': [1,2,3,4,5,6],
        'sratio' : [10,20,30,40,50,60],
        'org' : [100,200,300,400,500,600],
        'sprice' : [1,2,3,4,5,6],
        'private' : [10,20,30,40,50,60] 
        }

# print(date)

df = DataFrame(date, columns=['private', 'org', 'sratio', 'sprice', 'foreigner'], index=['2026-05-01', '2026-05-02', '2026-05-03', '2026-05-04', '2026-05-05', '2026-05-06'])

# # slice data
# print(df['private'])

# # loc 
# print(df.loc['2026-05-02'])

print(df)
# Out:
#             private  org  sratio  sprice  foreigner
# 2026-05-01       10  100      10       1          1
# 2026-05-02       20  200      20       2          2
# 2026-05-03       30  300      30       3          3
# 2026-05-04       40  400      40       4          4
# 2026-05-05       50  500      50       5          5
# 2026-05-06       60  600      60       6          6

# %%
df.transpose()
print(df.T)
print(df)
# Out:
#            2026-05-01  2026-05-02  2026-05-03  2026-05-04  2026-05-05  \
# private            10          20          30          40          50
# org               100         200         300         400         500
# sratio             10          20          30          40          50
# sprice              1           2           3           4           5
# foreigner           1           2           3           4           5
#
#            2026-05-06
# private            60
# org               600
# sratio             60
# sprice              6
# foreigner           6
#             private  org  sratio  sprice  foreigner
# 2026-05-01       10  100      10       1          1
# 2026-05-02       20  200      20       2          2
# 2026-05-03       30  300      30       3          3
# 2026-05-04       40  400      40       4          4
# 2026-05-05       50  500      50       5          5
# 2026-05-06       60  600      60       6          6

# %%
# !type c:\work\ex1.csv
# Out:
# id, name, price, description
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
df2 = pd.read_csv('c:\\work\\ex1.csv', encoding='cp949', sep=',')
print(df2)
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            3 non-null      int64
#  1    name         3 non-null      str
#  2    price        3 non-null      int64
#  3    description  3 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 228.0 bytes

# %%
# !type c:\work\ex2.csv
# Out:
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
df3 = pd.read_csv('c:\\work\\ex2.csv', encoding='cp949', sep=',', header=None, names=['id', 'name', 'price', 'description'])
print(df3)
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
# !type c:\work\ex3.csv
# Out:
# data1 data2 data3
# 1.2 2.3 1.3
# 0.1 1.5 2.5
# 3.1 3.2 3.3

# %%
df4 = pd.read_table('c:\\work\\ex3.csv', sep=r'\s+')
print(df4)
# Out:
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
df5 = pd.read_csv('c:\\work\\ex1.csv', encoding='cp949', sep='::', engine='python')
print(df5)
# Out:
#    id      name    price         description
# 0   1    iphone  1990000           iphone 17
# 1   2   android  1590000       samsung phone
# 2   3  winphone   850000  microsoft winphone

# %%
import matplotlib.pyplot as plt
# excel data loading
dfExcel = pd.read_excel('c:\\work\\demo.xlsx', sheet_name='Sheet1')
print(dfExcel)

# chart 를 출력
fig = plt.figure()
# 1행 1열의 첫 번째 subplot
ax = fig.add_subplot(1,1,1)
# 나이 컬럼의 히스토그램을 그립니다.
ax.hist(dfExcel['나이'], bins=5, rwidth=3, color='pink')
# Out:
#      사번 성별  나이  판매금액   수입
# 0  E001  M  34   123  350
# 1  E002  F  40   114  450
# 2  E003  F  37   135  169
# 3  E004  M  30   139  189
# 4  E005  F  44   117  183
# 5  E006  M  36   121   90
# 6  E007  M  32   133  166
# 7  E008  F  26   140  120
# 8  E009  M  32   133   75
# 9  E010  M  36   133   40
# (array([1., 3., 3., 2., 1.]),
#  array([26. , 29.6, 33.2, 36.8, 40.4, 44. ]),
#  <BarContainer object of 5 artists>)
